# %% [markdown]
# #pandas
# 파이썬계의 엑셀

# %%
# 정형데이터, 이차원 데이터

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
# !pip install pandas=='2.0.2'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 113.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 40.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.2 which is incompatible.
# ...

# %% [markdown]
# ###생성

# %%
# DataFrame()
height = [170,185,172,187,161]
weight = [76,82,71,79,61]
blood = ['O','A','A','AB','B']

# %%
df= pd.DataFrame([height,weight,blood])
df
# 이렇게 하면 안된다. 각각 사람이 새로로 나열되게
# Out:
#      0    1    2    3    4
# 0  170  185  172  187  161
# 1   76   82   71   79   61
# 2    O    A    A   AB    B

# %%
df= df.T
# 전치 해서 요렇게 만들기

# %%
df.columns = ['height','weight', 'blood']
df
# 왼쪽에 인덱스 위에가 컴럼 이름
# Out:
#   height weight blood
# 0    170     76     O
# 1    185     82     A
# 2    172     71     A
# 3    187     79    AB
# 4    161     61     B

# %%
info = {'height': [170,185,172,187,161],
'weight': [76,82,71,79,61],
'blood' : ['O','A','A','AB','B']}
type(info)
# Out:
# dict

# %%
# 데이터의 형식, 정보,숫자타입만 보기
df.shape
df.info()
df.describe()

df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  5 non-null      object
#  1   weight  5 non-null      object
#  2   blood   5 non-null      object
# dtypes: object(3)
# memory usage: 248.0+ bytes
# Index(['height', 'weight', 'blood'], dtype='object')

# %%
type(df)

df.index
# 인덱스 뽑기
df.values
# 데이터만 뽑기
# Out:
# array([[170, 76, 'O'],
#        [185, 82, 'A'],
#        [172, 71, 'A'],
#        [187, 79, 'AB'],
#        [161, 61, 'B']], dtype=object)

# %%
#indexing-height

df['height']
# Out:
# 0    170
# 1    185
# 2    172
# 3    187
# 4    161
# Name: height, dtype: object

# %%
type(df['height'])
# Out:
# pandas.core.series.Series

# %%
df[['height']]
# 위랑 표시가 다른데
# 데이터 프레임 형식, 위에는 시리즈형식
# Out:
#   height
# 0    170
# 1    185
# 2    172
# 3    187
# 4    161

# %%
# !wget https://raw.githubusercontent.com/devdio/flyai_datasets/main/titanic.csv
# 인터넷 데이터 가져오기
# Out:
# --2023-06-26 06:39:01--  https://raw.githubusercontent.com/devdio/flyai_datasets/main/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67691 (66K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  66.10K  --.-KB/s    in 0.01s
#
# 2023-06-26 06:39:01 (4.86 MB/s) - ‘titanic.csv’ saved [67691/67691]

# %%
df= pd.read_csv('titanic.csv')
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# non null 결측치 보기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.isna()

df.isna().sum (axis=0)
# 1은 T, 0은 F
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
info = {'height': [170,185,np.nan,187,161],
'weight': [76,82,71,79,61],
'blood' : ['O','A','A','AB','B']}

df = pd.DataFrame(info)
df
# np.nan 데이터 안들어있다!
# Out:
#    height  weight blood
# 0   170.0      76     O
# 1   185.0      82     A
# 2     NaN      71     A
# 3   187.0      79    AB
# 4   161.0      61     B

# %%
df.isna().sum(axis=0)
# Out:
# height    1
# weight    0
# blood     0
# dtype: int64

# %%
#결측치 없애기 na가 포함된 row 날리기
df.dropna()
# Out:
#    height  weight blood
# 0   170.0      76     O
# 1   185.0      82     A
# 3   187.0      79    AB
# 4   161.0      61     B

# %%
# df에 할당하는 방법 두가지
df.dropna(inplace=True)
df= df.dropna()

# %%
# 원본 데이터 복사
df1= df.copy()

# %%
df1.fillna(0)
# 결측치 0으로 채우기

df1['height'].fillna(df1['height'].mean())
# 평균으로 채우기
# Out:
#    height  weight blood
# 0   170.0      76     O
# 1   185.0      82     A
# 2     0.0      71     A
# 3   187.0      79    AB
# 4   161.0      61     B

# %%
df
# Out:
#    height  weight  blood
# 0   False   False  False
# 1   False   False  False
# 2    True   False  False
# 3   False   False  False
# 4   False   False  False

# %%
# 결측치 행 뽑아오기

df[df['height'].isna()]
# Out:
#    height  weight blood
# 2     NaN      71     A

# %%
titanic= pd.read_csv('titanic.csv')
titanic.head()

titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 엠바크 두개는 뭘까? 날려도 될까?
df1= titanic[titanic['Age'].isna()]

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3rd    491
# 1st    216
# 2nd    184
# Name: count, dtype: int64

# %%
titanic[titanic['Pclass'==1st]]
# 1등급인거 뽑아보

# %%
df= titanic.copy()
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[0:1]
# Out:
#    PassengerId Survived Pclass                     Name   Sex   Age  SibSp  \
# 0            1     lost    3rd  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# iloc[] -->숫자로 지정
# loc[]
df.iloc[0:10,0:3]
# Out:
#    PassengerId Survived Pclass
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
# 5            6     lost    3rd
# 6            7     lost    1st
# 7            8     lost    3rd
# 8            9    saved    3rd
# 9           10    saved    2nd

# %%
df.loc[0:3, ['Pclass','Age']]
# Out:
#   Pclass   Age
# 0    3rd  22.0
# 1    1st  38.0
# 2    3rd  26.0
# 3    1st  35.0

# %%
df.loc[df['Pclass']== '1st',['Age','Pclass']]
# Out:
#       Age Pclass
# 1    38.0    1st
# 3    35.0    1st
# 6    54.0    1st
# 11   58.0    1st
# 23   28.0    1st
# ..    ...    ...
# 871  47.0    1st
# 872  33.0    1st
# 879  56.0    1st
# 887  19.0    1st
# 889  26.0    1st
#
# [216 rows x 2 columns]

# %%
df.loc[(df['Pclass']== '1st') & (df['Age']>=50)]
# Out:
#      PassengerId Survived Pclass  \
# 6              7     lost    1st
# 11            12    saved    1st
# 54            55     lost    1st
# 96            97     lost    1st
# 124          125     lost    1st
# 155          156     lost    1st
# 170          171     lost    1st
# 174          175     lost    1st
# 177          178     lost    1st
# 195          196    saved    1st
# 252          253     lost    1st
# 262          263     lost    1st
# 268          269    saved    1st
# 275          276    saved    1st
# 299          300    saved    1st
# 366          367    saved    1st
# 434          435     lost    1st
# 438          439     lost    1st
# 449          450    saved    1st
# 456          457     lost    1st
# 467          468     lost    1st
# 487          488     lost    1st
# 492          493     lost    1st
# 493          494     lost    1st
# 496          497    saved    1st
# 513          514    saved    1st
# 544          545     lost    1st
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId Survived Pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df3= df[['Name', 'Sex', 'Age']]
df3.shape
# Out:
# (891, 3)

# %%
# 불필요한 항 날리기,axis 지정 해주기
df3.drop('Name',axis=1)
# Out:
#         Sex   Age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
#  결측치 로우 날리기
df3= df3.dropna(axis=0)

# %%
# 새로운 열etc 추가
df3['etc']=df3['Age']*3
df3.head()
# Out:
#                                                 Name     Sex   Age    etc
# 0                            Braund, Mr. Owen Harris    male  22.0   66.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  114.0
# 2                             Heikkinen, Miss. Laina  female  26.0   78.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  105.0
# 4                           Allen, Mr. William Henry    male  35.0  105.0

# %%
df.groupby['Pclass'].mean()
# 확인하기
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-d208f0fa61e9> in <cell line: 1>()
# ----> 1 df.groupby['Pclass'].mean()
#       2 # 확인하기
#
# TypeError: 'method' object is not subscriptable

# %%
# 카테고리 gvm?
